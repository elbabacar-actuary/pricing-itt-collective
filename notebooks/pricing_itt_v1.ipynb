# %%
import pandas as pd

df_clean = pd.read_csv("../data/processed/claims_cleaned.csv")
df_clean.head()
# Out:
#   insured_id date_of_birth claim_start_date  age_at_claim  annual_salary  \
# 0       A001    1978-04-12       2023-03-12     44.914442          45000
# 1       A002    1984-11-03       2023-02-05     38.255989          38000
# 2       A004    1992-07-21       2023-06-01     30.861054          52000
# 3       A006    1970-12-30       2023-09-10     52.695414          41000
# 4       A007    2005-01-01       2023-04-20     18.297057          22000
#
#    claim_duration_days  daily_benefit
# 0                 30.0            110
# 1                 15.0             90
# 2                 10.0            130
# 3                 40.0            105
# 4                  5.0             60

# %%
# Construction de la base “pricing” par assuré

pricing_base = (
    df_clean
    .groupby("insured_id")
    .agg(
        nb_claims=("claim_start_date", "count"),
        total_days=("claim_duration_days", "sum"),
        avg_daily_benefit=("daily_benefit", "mean"),
        annual_salary=("annual_salary", "first"),
        avg_age=("age_at_claim", "mean")
    )
    .reset_index()
)

pricing_base["exposure_years"] = 1.0  # simplification V1
# Out:
#   insured_id  nb_claims  total_days  avg_daily_benefit  annual_salary  \
# 0       A001          1        30.0              110.0          45000
# 1       A002          1        15.0               90.0          38000
# 2       A004          1        10.0              130.0          52000
# 3       A006          1        40.0              105.0          41000
# 4       A007          1         5.0               60.0          22000
#
#      avg_age  exposure_years
# 0  44.914442             1.0
# 1  38.255989             1.0
# 2  30.861054             1.0
# 3  52.695414             1.0
# 4  18.297057             1.0

# %%
# Calcul de la prime pure (ITT V1)

pricing_base["frequency"] = pricing_base["nb_claims"] / pricing_base["exposure_years"]
pricing_base["avg_duration"] = pricing_base["total_days"] / pricing_base["nb_claims"]
pricing_base["avg_claim_cost"] = pricing_base["avg_duration"] * pricing_base["avg_daily_benefit"]
pricing_base["pure_premium"] = pricing_base["frequency"] * pricing_base["avg_claim_cost"]

pricing_base[[
    "insured_id",
    "frequency",
    "avg_duration",
    "avg_daily_benefit",
    "avg_claim_cost",
    "pure_premium"
]]
# Out:
#   insured_id  frequency  avg_duration  avg_daily_benefit  avg_claim_cost  \
# 0       A001        1.0          30.0              110.0          3300.0
# 1       A002        1.0          15.0               90.0          1350.0
# 2       A004        1.0          10.0              130.0          1300.0
# 3       A006        1.0          40.0              105.0          4200.0
# 4       A007        1.0           5.0               60.0           300.0
#
#    pure_premium
# 0        3300.0
# 1        1350.0
# 2        1300.0
# 3        4200.0
# 4         300.0

# %%
# Sensitive checks
# Statistiques

pricing_base[[
    "frequency","avg_duration","avg_daily_benefit","avg_claim_cost","pure_premium"
]].describe()
# Out:
#        frequency  avg_duration  avg_daily_benefit  avg_claim_cost  \
# count        5.0       5.00000            5.00000        5.000000
# mean         1.0      20.00000           99.00000     2090.000000
# std          0.0      14.57738           26.07681     1604.057356
# min          1.0       5.00000           60.00000      300.000000
# 25%          1.0      10.00000           90.00000     1300.000000
# 50%          1.0      15.00000          105.00000     1350.000000
# 75%          1.0      30.00000          110.00000     3300.000000
# max          1.0      40.00000          130.00000     4200.000000
#
#        pure_premium
# count      5.000000
# mean    2090.000000
# std     1604.057356
# min      300.000000
# 25%     1300.000000
# 50%     1350.000000
# 75%     3300.000000
# max     4200.000000

# %%
# Sensitive checks
# Top primes (detection d'extremes)

pricing_base.sort_values("pure_premium", ascending=False).head(10)
# Out:
#   insured_id  nb_claims  total_days  avg_daily_benefit  annual_salary  \
# 3       A006          1        40.0              105.0          41000
# 0       A001          1        30.0              110.0          45000
# 1       A002          1        15.0               90.0          38000
# 2       A004          1        10.0              130.0          52000
# 4       A007          1         5.0               60.0          22000
#
#      avg_age  exposure_years  frequency  avg_duration  avg_claim_cost  \
# 3  52.695414             1.0        1.0          40.0          4200.0
# 0  44.914442             1.0        1.0          30.0          3300.0
# 1  38.255989             1.0        1.0          15.0          1350.0
# 2  30.861054             1.0        1.0          10.0          1300.0
# 4  18.297057             1.0        1.0           5.0           300.0
#
#    pure_premium
# 3        4200.0
# 0        3300.0
# 1        1350.0
# 2        1300.0
# 4         300.0

# %%
# Sensitive checks
# Verif divisions / valeurs invalides

checks = {
    "nb_claims_zero": int((pricing_base["nb_claims"] == 0).sum()),
    "pure_premium_negative": int((pricing_base["pure_premium"] < 0).sum()),
    "pure_premium_nan": int(pricing_base["pure_premium"].isna().sum()),
    "avg_duration_negative": int((pricing_base["avg_duration"] < 0).sum()),
    "avg_duration_nan": int(pricing_base["avg_duration"].isna().sum()),
}
checks
# Out:
# {'nb_claims_zero': 0,
#  'pure_premium_negative': 0,
#  'pure_premium_nan': 0,
#  'avg_duration_negative': 0,
#  'avg_duration_nan': 0}
